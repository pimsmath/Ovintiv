# %%
import pandas as pd
import plotly_express as px
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import math
import scipy.stats as st
import datetime
from sklearn import linear_model

# %%
def change_date(s):
    s = datetime.datetime.strptime(s, "%Y/%m/%d")  
    s = str(s)  
    return s[:10] 
price = pd.read_csv( "PricesFile1.csv")
price_wti=price[price['priceindex'].isin(['WTI NYMEX LIGHT SWEET'])]
price_wti['pricedate'] = price_wti['pricedate'].map(change_date) 
price_wti['delivdate'] = price_wti['delivdate'].map(change_date) 
price_wti=price_wti.sort_values(by=['pricedate','delivdate'], ascending=[True, True])
price_wti.reset_index(drop=True, inplace=True)
price_wti
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  priceindex   pricedate   delivdate   price
# 0     WTI NYMEX LIGHT SWEET  2020-03-02  2020-03-01  53.779
# 1     WTI NYMEX LIGHT SWEET  2020-03-02  2020-04-01  46.749
# ...

# %%
whole = pd.read_csv( "master_wti_complete.csv")
whole
# Out:
#                   priceindex   pricedate   delivdate   price  \
# 0      WTI NYMEX LIGHT SWEET  2020-03-02  2020-04-01  46.749
# 1      WTI NYMEX LIGHT SWEET  2020-03-02  2020-04-01  46.749
# 2      WTI NYMEX LIGHT SWEET  2020-03-02  2020-04-01  46.749
# 3      WTI NYMEX LIGHT SWEET  2020-03-02  2020-04-01  46.749
# 4      WTI NYMEX LIGHT SWEET  2020-03-02  2020-04-01  46.749
# ...                      ...         ...         ...     ...
# 78537  WTI NYMEX LIGHT SWEET  2020-05-29  2022-12-01  41.879
# 78538  WTI NYMEX LIGHT SWEET  2020-05-29  2022-12-01  41.879
# 78539  WTI NYMEX LIGHT SWEET  2020-05-29  2022-12-01  41.879
# 78540  WTI NYMEX LIGHT SWEET  2020-05-29  2022-12-01  41.879
# 78541  WTI NYMEX LIGHT SWEET  2020-05-29  2022-12-01  41.879
#
#                          key                     duration  duration_months  \
# 0      2020-03-02,2020-04-01   30 days 00:00:00.000000000              1.0
# 1      2020-03-02,2020-04-01   30 days 00:00:00.000000000              1.0
# ...

# %%
plt.rcParams['figure.figsize'] = (25,10)
plt.subplot(221) 
plt.plot(whole[whole['pricedate']=='2020-03-02']['delivdate'],whole[whole['pricedate']=='2020-03-02']['price'])
plt.plot(whole[whole['pricedate']=='2020-03-02']['delivdate'],whole[whole['pricedate']=='2020-03-02']['price'],'o')
plt.xlabel('delivery date',size=15)
plt.ylabel('future price',size=15)
plt.title('2020-03-02',size=15)
plt.xticks(rotation=300)
plt.subplot(222) 
plt.plot(whole[whole['pricedate']=='2020-04-01']['delivdate'],whole[whole['pricedate']=='2020-04-01']['price'])
plt.plot(whole[whole['pricedate']=='2020-04-01']['delivdate'],whole[whole['pricedate']=='2020-04-01']['price'],'o')
plt.xlabel('delivery date',size=15)
plt.ylabel('future price',size=15)
plt.title('2020-04-01',size=15)
plt.xticks(rotation=300)
plt.tight_layout(5) 
plt.subplot(223) 
plt.plot(whole[whole['pricedate']=='2020-04-20']['delivdate'],whole[whole['pricedate']=='2020-04-20']['price'])
plt.plot(whole[whole['pricedate']=='2020-04-20']['delivdate'],whole[whole['pricedate']=='2020-04-20']['price'],'o')
plt.xlabel('delivery date',size=15)
plt.ylabel('future price',size=15)
plt.title('2020-04-20',size=15)
plt.xticks(rotation=300)
plt.subplot(224) 
plt.plot(whole[whole['pricedate']=='2020-05-29']['delivdate'],whole[whole['pricedate']=='2020-05-29']['price'])
plt.plot(whole[whole['pricedate']=='2020-05-29']['delivdate'],whole[whole['pricedate']=='2020-05-29']['price'],'o')
plt.xlabel('delivery date',size=15)
plt.ylabel('future price',size=15)
plt.title('2020-05-29',size=15)
plt.xticks(rotation=300)

# %%
pricedate=whole['pricedate'].unique()
S=[]
for i in list(pricedate):
    S.append(whole[whole['pricedate']==i]['price'].reset_index(drop=True))

# %%
a=[]
b=[]
e=[]
for i in range(len(pricedate)):
    n=len(S[i])
    Sx=sum(S[i][0:n-1])
    Sy=sum(S[i][1:n])
    Sxx=sum(S[i][0:n-1]**2)
    Sxy=sum(S[i][0:n-1]*S[i][1:n].reset_index(drop=True))
    Syy=sum(S[i][1:n]**2)
    a.append((n*Sxy-Sx*Sy)/(n*Sxx-Sx**2))
    b.append((Sy-a[i]*Sx)/n)
    e.append(np.sqrt((n*Syy-Sy**2-a[i]*(n*Sxy-Sx*Sy))/(n*(n-2))))
parameter=pd.DataFrame({'a':a,'b':b,'error':e})
parameter
# Out:
#            a         b     error
# 0   1.000124 -0.004304  0.010913
# 1   1.000146 -0.005582  0.009840
# 2   1.000164 -0.006038  0.012056
# 3   1.000342 -0.013708  0.014839
# 4   1.000679 -0.024364  0.034241
# ..       ...       ...       ...
# 58  1.000310 -0.005196  0.039103
# 59  1.000374 -0.007878  0.039109
# 60  1.000477 -0.010157  0.045094
# 61  1.000798 -0.023572  0.038930
# 62  1.000733 -0.023065  0.032799
#
# [63 rows x 3 columns]

# %%
a=parameter['a'][34]
b=parameter['b'][34]
e=parameter['error'][34]
delta=1/12
#delta=1
mean_reversion=-np.log(a)/delta
mean_mu=b/(1-a)
sigma=e*np.sqrt(-2*np.log(a)/delta/(1-a**2))
print('mean_reversion:%f, mean:%f, volatility: %f'%(mean_reversion,mean_mu,sigma))
# Out:
# mean_reversion:1.746599, mean:33.099896, volatility: 5.631950

# %%
'''
a=parameter['a'].mean()
b=parameter['b'].mean()
e=parameter['error'].mean()
delta=1
mean_reversion=-np.log(a)/delta
mean_mu=b/(1-a)
sigma=e*np.sqrt(-2*np.log(a)/delta/(1-a**2))
print('mean_reversion:%f, mean:%f, volatility: %f'%(mean_reversion,mean_mu,sigma))
'''

# %%
F_0=price_wti[price_wti['pricedate']=='2020-04-20']['price'].reset_index(drop=True)[0]
lam=((S[34][0]-F_0)/F_0-whole[whole['price']==S[34][0]]['bidrate'].values)/sigma
lam
# Out:
# array([-0.59886598])

# %%
whole[whole['price']==S[34][0]]['bidrate']

# %%
neg=whole[(whole['pricedate']=='2020-04-20')&(whole['delivdate']=='2020-05-01')]
neg
# Out:
#                   priceindex   pricedate   delivdate   price  \
# 43198  WTI NYMEX LIGHT SWEET  2020-04-20  2020-05-01 -37.631
#
#                          key                    duration  duration_months  \
# 43198  2020-04-20,2020-05-01  11 days 00:00:00.000000000              0.0
#
#                volatilityindex  strikeprice  volatility pricedate_r maturity  \
# 43198  V_WTI NYMEX LIGHT SWEET         43.5       0.001  2020-04-20       1M
#
#        bidrate  number MorY  months
# 43198    0.695       1    M       1

# %%
b_star=mean_mu-lam*sigma/mean_reversion
Te=1/360
d=(np.exp(-mean_reversion*Te)*(F_0-b_star)-neg['strikeprice'].values)/(sigma*np.sqrt((1-np.exp(-2*mean_reversion*Te))/2/mean_reversion))
C=np.exp(-neg['bidrate'].values*Te/100)*((np.exp(mean_reversion*Te)*(F_0-b_star)-neg['strikeprice'].values)*st.norm.cdf(d)+sigma*np.sqrt((1-np.exp(-2*mean_reversion*Te))/2/mean_reversion)*st.norm.pdf(d))
print('call option price:%f'%C)
# Out:
# call option price:0.000000

# %%
P=C+neg['strikeprice'].values*np.exp(-neg['bidrate'].values/100*Te)-F_0
print('put option price:%f'%P)
# Out:
# put option price:21.070160

# %%
#April 1st T=3 Vasicek
F_0=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-04-01')]['price'].values
F_T=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-07-01')]['price'].mean()
r=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-07-01')]['bidrate'].mean()
T=3/12
Te=T-10/360
a=parameter['a'][22]
b=parameter['b'][22]
e=parameter['error'][22]
delta=1/12
mean_reversion=-np.log(a)/delta
mean_mu=b/(1-a)
sigma=e*np.sqrt(-2*np.log(a)/delta/(1-a**2))
print('mean_reversion:%f, mean:%f, volatility: %f'%(mean_reversion,mean_mu,sigma))
lam=((F_T-F_0)/F_0-r)/sigma
b_star=mean_mu-lam*sigma/mean_reversion

# %%
K=25
d=(np.exp(-mean_reversion*Te)*(F_0-b_star)-K)/(sigma*np.sqrt((1-np.exp(-2*mean_reversion*Te))/2/mean_reversion))
C=np.exp(-r*Te/100)*((np.exp(mean_reversion*Te)*(F_0-b_star)-K)*st.norm.cdf(d)+sigma*np.sqrt((1-np.exp(-2*mean_reversion*Te))/2/mean_reversion)*st.norm.pdf(d))
print('call option price:%f'%C)
P=C+K*np.exp(-r*Te/100)-F_0
print('put option price:%f'%P)

# %%
K=27
d=(np.exp(-mean_reversion*Te)*(F_0-b_star)-K)/(sigma*np.sqrt((1-np.exp(-2*mean_reversion*Te))/2/mean_reversion))
C=np.exp(-r*Te/100)*((np.exp(mean_reversion*Te)*(F_0-b_star)-K)*st.norm.cdf(d)+sigma*np.sqrt((1-np.exp(-2*mean_reversion*Te))/2/mean_reversion)*st.norm.pdf(d))
print('call option price:%f'%C)
P=C+K*np.exp(-r*Te/100)-F_0
print('put option price:%f'%P)
# d?

# %%
#April 1st T=3 Bachelier
d=(F_0-K)/sigma/np.sqrt(Te)
C=np.exp(-r*Te/100)*((F_0-K)*st.norm.cdf(d)+sigma*np.sqrt(Te)*st.norm.pdf(d))
print('call option price:%f'%C)

# %%
#April 1st T=3 Black 76
F_0=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-04-01')]['price'].values
F_T=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-07-01')]['price'].mean()
r=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-07-01')]['bidrate'].mean()
K=25
sigma=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-07-01')&(whole['strikeprice']==K)]['volatility']
T=3/12
Te=T-10/360
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r/100*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)
# Out:
# call option price:3.854632

# %%
#April 1st T=3 Black 76
K=27
sigma=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-07-01')&(whole['strikeprice']==K)]['volatility']
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r/100*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)
# Out:
# call option price:3.125142

# %%
#April 1st T=3 Black 76
K=28
sigma=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-07-01')&(whole['strikeprice']==K)]['volatility']
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r/100*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)
# Out:
# call option price:2.809653

# %%
#April 1st T=6 Black 76
F_T=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-10-01')]['price'].mean()
r=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-10-01')]['bidrate'].mean()
K=25
sigma=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-10-01')&(whole['strikeprice']==K)]['volatility']
T=6/12
Te=T-10/360
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r/100*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)
# Out:
# call option price:3.690079

# %%
#April 1st T=6 Black 76
K=27
sigma=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-10-01')&(whole['strikeprice']==K)]['volatility']
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r/100*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)
# Out:
# call option price:2.981882

# %%
#April 1st T=6 Black 76
K=28
sigma=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-10-01')&(whole['strikeprice']==K)]['volatility']
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r/100*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)
# Out:
# call option price:2.677836

# %%
#May 1st T=6 Black 76
F_0=whole[(whole['pricedate']=='2020-05-01')&(whole['delivdate']=='2020-05-01')]['price'].values
F_T=whole[(whole['pricedate']=='2020-05-01')&(whole['delivdate']=='2020-11-01')]['price'].mean()
r=whole[(whole['pricedate']=='2020-05-01')&(whole['delivdate']=='2020-11-01')]['bidrate'].mean()
K=25
sigma=whole[(whole['pricedate']=='2020-05-01')&(whole['delivdate']=='2020-11-01')&(whole['strikeprice']==K)]['volatility']
T=6/12
Te=T-10/360
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r/100*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)
# Out:
# call option price:0.064182

# %%
#May 1st T=6 Black 76
K=26
sigma=whole[(whole['pricedate']=='2020-05-01')&(whole['delivdate']=='2020-11-01')&(whole['strikeprice']==K)]['volatility']
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r/100*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)
# Out:
# call option price:0.044752

# %%
#May 1st T=6 Black 76
K=27
sigma=whole[(whole['pricedate']=='2020-05-01')&(whole['delivdate']=='2020-11-01')&(whole['strikeprice']==K)]['volatility']
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r/100*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)
# Out:
# call option price:0.031906

# %%
#April 1st T=6 Vasicek
F_0=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-04-01')]['price']
F_T=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-10-01')]['price'].mean()
r=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-10-01')]['bidrate'].mean()
T=6/12
Te=T-1/36
lam=((F_T-F_0)/F_0-r)/sigma
b_star=mean_mu-lam*sigma/mean_reversion

# %%
K=25
d=(np.exp(-mean_reversion*Te)*(F_0-b_star)-K)/(sigma*np.sqrt((1-np.exp(-2*mean_reversion*Te))/2/mean_reversion))
C=np.exp(-r*Te)*((np.exp(mean_reversion*Te)*(F_0-b_star)-K)*st.norm.cdf(d)+sigma*np.sqrt((1-np.exp(-2*mean_reversion*Te))/2/mean_reversion)*st.norm.pdf(d))
print('call option price:%f'%C)

# %%
#April 1st T=6 Bachelier
d=(F_0-K)/sigma/np.sqrt(Te)
C=np.exp(-r*Te)*((F_0-K)*st.norm.cdf(d)+sigma*np.sqrt(Te)*st.norm.pdf(d))
print('call option price:%f'%C)

# %%
#April 1st T=6 Black 76
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)

# %%
#April 1st T=12
F_0=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2020-04-01')]['price']
F_T=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2021-04-01')]['price'].mean()
r=whole[(whole['pricedate']=='2020-04-01')&(whole['delivdate']=='2021-04-01')]['bidrate'].mean()
T=1
Te=T-1/36
lam=((F_T-F_0)/F_0-r)/sigma
b_star=mean_mu-lam*sigma/mean_reversion

# %%
K=25
d=(np.exp(-mean_reversion*Te)*(F_0-b_star)-K)/(sigma*np.sqrt((1-np.exp(-2*mean_reversion*Te))/2/mean_reversion))
C=np.exp(-r*Te)*((np.exp(mean_reversion*Te)*(F_0-b_star)-K)*st.norm.cdf(d)+sigma*np.sqrt((1-np.exp(-2*mean_reversion*Te))/2/mean_reversion)*st.norm.pdf(d))
print('call option price:%f'%C)

# %%
#April 1st T=12 Bachelier
d=(F_0-K)/sigma/np.sqrt(Te)
C=np.exp(-r*Te)*((F_0-K)*st.norm.cdf(d)+sigma*np.sqrt(Te)*st.norm.pdf(d))
print('call option price:%f'%C)

# %%
#April 1st T=12 Black 76
d1=(np.log(F_0/K)+(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
d2=(np.log(F_0/K)-(sigma**2)*Te/2)/(sigma*np.sqrt(Te))
C=np.exp(-r*Te)*(F_0*st.norm.cdf(d1)-K*st.norm.cdf(d2))
print('call option price:%f'%C)
