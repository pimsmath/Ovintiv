# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import base64
import pandas as pd
from IPython.display import HTML

def create_download_link( df, title = "Download CSV file", filename = "data.csv"):
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)
prices=pd.read_csv("PricesFile1.csv")

# %%
df_wti=prices[prices.priceindex=='WTI NYMEX LIGHT SWEET']
df_wti=df_wti[pd.to_datetime(df_wti.pricedate) < pd.to_datetime(df_wti.delivdate)]
year_2020=['2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01','2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01','2020-12-01']
year_2021=['2021-01-01', '2021-02-01', '2021-03-01','2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01','2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01',
       '2021-12-01']
year_2022=['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01','2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01',
       '2022-12-01']
df_wti21= df_wti[df_wti.delivdate.isin(year_2021)]
df_wti22= df_wti[df_wti.delivdate.isin(year_2022)]
df_wti20= df_wti[df_wti.delivdate.isin(year_2020)]
df_wti.rename(columns={'priceindex':'volatilityindex','pricedate': 'volatilitydate', 'delivdate': 'begtime'},inplace=True)
df_wti
# Out:
#             volatilityindex volatilitydate     begtime   price
# 4071  WTI NYMEX LIGHT SWEET     2020-03-02  2020-04-01  46.749
# 4072  WTI NYMEX LIGHT SWEET     2020-03-02  2020-05-01  46.919
# 4073  WTI NYMEX LIGHT SWEET     2020-03-02  2020-06-01  47.049
# 4074  WTI NYMEX LIGHT SWEET     2020-03-02  2020-07-01  47.139
# 4075  WTI NYMEX LIGHT SWEET     2020-03-02  2020-08-01  47.199
# ...                     ...            ...         ...     ...
# 6125  WTI NYMEX LIGHT SWEET     2020-05-29  2022-08-01  41.099
# 6126  WTI NYMEX LIGHT SWEET     2020-05-29  2022-09-01  41.289
# 6127  WTI NYMEX LIGHT SWEET     2020-05-29  2022-10-01  41.479
# 6128  WTI NYMEX LIGHT SWEET     2020-05-29  2022-11-01  41.679
# 6129  WTI NYMEX LIGHT SWEET     2020-05-29  2022-12-01  41.879
#
# [1997 rows x 4 columns]

# %%
df_wti_grouped=df_wti.groupby(by=['volatilitydate','begtime']).mean()
df_wti_grouped
#create_download_link(df_wti_grouped)
# Out:
#                             price
# volatilitydate begtime
# 2020-03-02     2020-04-01  46.749
#                2020-05-01  46.919
#                2020-06-01  47.049
#                2020-07-01  47.139
#                2020-08-01  47.199
# ...                           ...
# 2020-05-29     2022-08-01  41.099
#                2022-09-01  41.289
#                2022-10-01  41.479
#                2022-11-01  41.679
#                2022-12-01  41.879
#
# [1997 rows x 1 columns]

# %%
## obtaining data for price from a specific date
#df_wti_grouped.get_group('2020-03-02')
df_wti_grouped_1 = df_wti_grouped.xs(df_wti_grouped.index.levels[0][0])
df_wti_grouped_1
# Out:
#              price
# begtime
# 2020-04-01  46.749
# 2020-05-01  46.919
# 2020-06-01  47.049
# 2020-07-01  47.139
# 2020-08-01  47.199
# 2020-09-01  47.249
# 2020-10-01  47.309
# 2020-11-01  47.399
# 2020-12-01  47.489
# 2021-01-01  47.549
# 2021-02-01  47.589
# 2021-03-01  47.629
# 2021-04-01  47.699
# 2021-05-01  47.759
# 2021-06-01  47.819
# 2021-07-01  47.849
# 2021-08-01  47.879
# 2021-09-01  47.929
# 2021-10-01  48.009
# 2021-11-01  48.099
# 2021-12-01  48.189
# 2022-01-01  48.209
# 2022-02-01  48.229
# 2022-03-01  48.269
# 2022-04-01  48.309
# 2022-05-01  48.369
# 2022-06-01  48.429
# 2022-07-01  48.439
# 2022-08-01  48.469
# 2022-09-01  48.509
# 2022-10-01  48.559
# 2022-11-01  48.609
# 2022-12-01  48.669

# %%
## For date specific 
df_wti_1=df_wti[df_wti.volatilitydate =='2020-03-06']
#df_wti_1=df_wti_1[df_wti_1.begtime =='2020-11-01']
df_wti_1.set_index(pd.to_datetime(df_wti_1.volatilitydate), inplace=True)
df_wti_1.drop(columns="volatilitydate", inplace=True)
df_wti_1
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                       volatilityindex     begtime   price
# volatilitydate
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-04-01  41.279
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-05-01  41.509
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-06-01  41.769
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-07-01  42.039
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-08-01  42.329
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-09-01  42.639
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-10-01  42.919
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-11-01  43.239
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-12-01  43.559
# ...

# %%
wti_imvl20=pd.read_csv("WTI_ImpliedVols2020.csv")
wti_imvl21=pd.read_csv("WTI_ImpliedVols2021.csv")
wti_imvl22=pd.read_csv("WTI_ImpliedVols2022.csv")
frames=[wti_imvl20,wti_imvl21,wti_imvl22]
wti_imvl = pd.concat(frames)
wti_imvl
# Out:
#               volatilityindex volatilitydate  strikeprice     begtime  \
# 0     V_WTI NYMEX LIGHT SWEET     2020-03-06         25.0  2020-11-01
# 1     V_WTI NYMEX LIGHT SWEET     2020-03-06         25.5  2020-11-01
# 2     V_WTI NYMEX LIGHT SWEET     2020-03-06         26.0  2020-11-01
# 3     V_WTI NYMEX LIGHT SWEET     2020-03-06         26.5  2020-11-01
# 4     V_WTI NYMEX LIGHT SWEET     2020-03-06         27.0  2020-11-01
# ...                       ...            ...          ...         ...
# 9634  V_WTI NYMEX LIGHT SWEET     2020-05-29         63.0  2022-12-01
# 9635  V_WTI NYMEX LIGHT SWEET     2020-05-29         63.5  2022-12-01
# 9636  V_WTI NYMEX LIGHT SWEET     2020-05-29         64.0  2022-12-01
# 9637  V_WTI NYMEX LIGHT SWEET     2020-05-29         64.5  2022-12-01
# 9638  V_WTI NYMEX LIGHT SWEET     2020-05-29         65.0  2022-12-01
#
#       volatility  \
# 0          0.475
# 1          0.471
# 2          0.467
# 3          0.463
# 4          0.458
# ...

# %%
wti_imvl_mar_6=wti_imvl[wti_imvl.volatilitydate =='2020-03-06']
for_mar_6=['2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01',
       '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01',
       '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01',
       '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
       '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01',
       '2021-12-01', '2022-01-01', '2022-02-01', '2022-03-01',
       '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01',
       '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01',
       '2022-12-01']
wti_imvl_mar_6=wti_imvl_mar_6[wti_imvl_mar_6.begtime.isin(for_mar_6)]
wti_imvl_mar_6.set_index(pd.to_datetime(wti_imvl_mar_6.volatilitydate), inplace=True)
wti_imvl_mar_6.drop(columns="volatilitydate", inplace=True)

#wti_imvl20_1['price'] = df_wti20_1.price
#wti_imvl20_1['irate'] = rates_7M.bidrate
#create_download_link(wti_imvl20_1)
wti_imvl_mar_6.drop(columns="volatilityindex\tvolatilitydate\tstrikeprice\tbegtime\tvolatility", inplace=True)
#wti_imvl_mar_6=wti_imvl_mar_6.groupby(['strikeprice','begtime']).mean()

#wti_imvl_mar_6=wti_imvl_mar_6.groupby('strikeprice').mean()
#wti_imvl_mar_6=wti_imvl_mar_6.reindex(['volatilityindex', 'strikeprice', 'begtime', 'volatility','price'])
#wti_imvl_mar_6.assign(price=np.nan)
wti_imvl_mar_6['price'] = pd.Series()
wti_imvl_mar_6
# Out:
# <ipython-input-10-c28acae878e9>:24: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   wti_imvl_mar_6['price'] = pd.Series()
#                         volatilityindex  strikeprice     begtime  volatility  \
# volatilitydate
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         25.0  2020-11-01       0.475
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         25.5  2020-11-01       0.471
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         26.0  2020-11-01       0.467
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         26.5  2020-11-01       0.463
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         27.0  2020-11-01       0.458
# ...                                 ...          ...         ...         ...
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         63.0  2022-12-01       0.209
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         63.5  2022-12-01       0.209
# ...

# %%
for i in range(len(wti_imvl_mar_6)):
    for j in range(len(df_wti_1)):
        if (wti_imvl_mar_6.begtime.iloc[i]==df_wti_1.begtime.iloc[j]):
            wti_imvl_mar_6.price.iloc[i]=df_wti_1.price[j]


#create_download_link(wti_imvl_mar_6)        
wti_imvl_mar_6
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                         volatilityindex  strikeprice     begtime  volatility  \
# volatilitydate
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         25.0  2020-11-01       0.475
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         25.5  2020-11-01       0.471
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         26.0  2020-11-01       0.467
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         26.5  2020-11-01       0.463
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         27.0  2020-11-01       0.458
# ...                                 ...          ...         ...         ...
# ...

# %%
wti_imvl_mar_6['int_rate'] = pd.Series(dtype='float64')
rates=pd.read_csv('InterestRates.csv')
rates_mar6=rates[rates.pricedate=='2020-03-06']
for i in range(len(wti_imvl_mar_6)):
    t=pd.to_datetime(wti_imvl_mar_6.begtime.iloc[i])
    m=t.month-3 # 3 beacuase of march is the starting month
    for j in range(len(rates_mar6)):
        if(int(rates_mar6.maturity.iloc[j][0])==m):
            wti_imvl_mar_6.int_rate.iloc[i]=rates_mar6.bidrate.iloc[j]
            break
        


wti_imvl_mar_6
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                         volatilityindex  strikeprice     begtime  volatility  \
# volatilitydate
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         25.0  2020-11-01       0.475
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         25.5  2020-11-01       0.471
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         26.0  2020-11-01       0.467
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         26.5  2020-11-01       0.463
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         27.0  2020-11-01       0.458
# ...                                 ...          ...         ...         ...
# ...

# %%
create_download_link(wti_imvl_mar_6)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>

# %%
#rates_8M=rates[rates.maturity=='8M']
#rates_8M=rates_8M[rates.pricedate=='2020-03-06']
#rates_8M.set_index(pd.to_datetime(rates_8M.pricedate), inplace=True)
#rates_8M.drop(columns="pricedate", inplace=True)
#int(rates_8M.maturity.iloc[0][0])==8
#type(rates_8M.bidrate.iloc[0])

# %%
#wti_imvl_mar_6['int_rate'] = rates_8M.bidrate
#wti_imvl_mar_6
# Out:
#                         volatilityindex  strikeprice     begtime  volatility  \
# volatilitydate
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         25.0  2020-11-01       0.475
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         25.5  2020-11-01       0.471
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         26.0  2020-11-01       0.467
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         26.5  2020-11-01       0.463
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         27.0  2020-11-01       0.458
# ...                                 ...          ...         ...         ...
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         63.0  2022-12-01       0.209
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         63.5  2022-12-01       0.209
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         64.0  2022-12-01       0.209
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         64.5  2022-12-01       0.208
# 2020-03-06      V_WTI NYMEX LIGHT SWEET         65.0  2022-12-01       0.208
#
# ...
