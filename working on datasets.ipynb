# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import base64
import pandas as pd
from IPython.display import HTML

def create_download_link( df, title = "Download CSV file", filename = "data.csv"):
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)
prices=pd.read_csv("PricesFile1.csv")

# %%
df_wti=prices[prices.priceindex=='WTI NYMEX LIGHT SWEET']
df_wti=df_wti[pd.to_datetime(df_wti.pricedate) < pd.to_datetime(df_wti.delivdate)]
year_2020=['2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01','2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01','2020-12-01']
year_2021=['2021-01-01', '2021-02-01', '2021-03-01','2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01','2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01',
       '2021-12-01']
year_2022=['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01','2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01',
       '2022-12-01']
df_wti21= df_wti[df_wti.delivdate.isin(year_2021)]
df_wti22= df_wti[df_wti.delivdate.isin(year_2022)]
df_wti20= df_wti[df_wti.delivdate.isin(year_2020)]
df_wti.rename(columns={'priceindex':'volatilityindex','pricedate': 'volatilitydate', 'delivdate': 'begtime'},inplace=True)
df_wti.volatilitydate.unique()
# Out:
# array(['2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#        '2020-03-06', '2020-03-09', '2020-03-10', '2020-03-11',
#        '2020-03-12', '2020-03-13', '2020-03-16', '2020-03-17',
#        '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-23',
#        '2020-03-24', '2020-03-25', '2020-03-26', '2020-03-27',
#        '2020-03-30', '2020-03-31', '2020-04-01', '2020-04-02',
#        '2020-04-03', '2020-04-06', '2020-04-07', '2020-04-08',
#        '2020-04-09', '2020-04-13', '2020-04-14', '2020-04-15',
#        '2020-04-16', '2020-04-17', '2020-04-20', '2020-04-21',
#        '2020-04-22', '2020-04-23', '2020-04-24', '2020-04-27',
#        '2020-04-28', '2020-04-29', '2020-04-30', '2020-05-01',
#        '2020-05-04', '2020-05-05', '2020-05-06', '2020-05-07',
#        '2020-05-08', '2020-05-11', '2020-05-12', '2020-05-13',
#        '2020-05-14', '2020-05-15', '2020-05-18', '2020-05-19',
#        '2020-05-20', '2020-05-21', '2020-05-22', '2020-05-26',
# ...

# %%
## For date specific 
df_wti_1=df_wti[df_wti.volatilitydate =='2020-03-06']
#df_wti_1=df_wti_1[df_wti_1.begtime =='2020-11-01']
df_wti_1.set_index(pd.to_datetime(df_wti_1.volatilitydate), inplace=True)
df_wti_1.drop(columns="volatilitydate", inplace=True)
df_wti_1
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                       volatilityindex     begtime   price
# volatilitydate
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-04-01  41.279
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-05-01  41.509
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-06-01  41.769
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-07-01  42.039
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-08-01  42.329
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-09-01  42.639
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-10-01  42.919
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-11-01  43.239
# 2020-03-06      WTI NYMEX LIGHT SWEET  2020-12-01  43.559
# ...

# %%
plt.rcParams['figure.figsize'] = (25,10)
plt.plot(df_wti_1.begtime,df_wti_1.price)
plt.xticks(rotation=90)
plt.title('future prices starting March 06, 2020')
# Out:
# Text(0.5, 1.0, 'future prices starting March 06, 2020')

# %%
df_wti_2=df_wti[df_wti.volatilitydate =='2020-03-16']
#df_wti_1=df_wti_1[df_wti_1.begtime =='2020-11-01']
df_wti_2.set_index(pd.to_datetime(df_wti_2.volatilitydate), inplace=True)
df_wti_2.drop(columns="volatilitydate", inplace=True)
plt.rcParams['figure.figsize'] = (25,10)
plt.plot(df_wti_2.begtime,df_wti_2.price)
plt.xticks(rotation=300)
plt.title('future prices starting March 16, 2020')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'future prices starting March 16, 2020')

# %%
df_wti_3=df_wti[df_wti.volatilitydate =='2020-04-01']
df_wti_3.set_index(pd.to_datetime(df_wti_3.volatilitydate), inplace=True)
df_wti_3.drop(columns="volatilitydate", inplace=True)
plt.rcParams['figure.figsize'] = (25,10)
plt.plot(df_wti_3.begtime,df_wti_3.price)
plt.xticks(rotation=300)
plt.title('future prices starting April 1, 2020')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'future prices starting April 1, 2020')

# %%
df_wti_4=df_wti[df_wti.volatilitydate =='2020-04-15']
df_wti_4.set_index(pd.to_datetime(df_wti_4.volatilitydate), inplace=True)
df_wti_4.drop(columns="volatilitydate", inplace=True)
plt.rcParams['figure.figsize'] = (25,10)
plt.plot(df_wti_4.begtime,df_wti_4.price)
plt.xticks(rotation=300)
plt.title('future prices starting April 15, 2020')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'future prices starting April 15, 2020')

# %%
df_wti_5=df_wti[df_wti.volatilitydate =='2020-04-24']
df_wti_5.set_index(pd.to_datetime(df_wti_5.volatilitydate), inplace=True)
df_wti_5.drop(columns="volatilitydate", inplace=True)
plt.rcParams['figure.figsize'] = (25,10)
plt.plot(df_wti_5.begtime,df_wti_5.price)
plt.xticks(rotation=300)
plt.title('future prices starting April 24, 2020')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'future prices starting April 24, 2020')

# %%
df_wti_6=df_wti[df_wti.volatilitydate =='2020-05-01']
df_wti_6.set_index(pd.to_datetime(df_wti_6.volatilitydate), inplace=True)
df_wti_6.drop(columns="volatilitydate", inplace=True)
plt.rcParams['figure.figsize'] = (25,10)
plt.plot(df_wti_6.begtime,df_wti_6.price)
plt.xticks(rotation=300)
plt.title('future prices starting May 1st, 2020')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'future prices starting May 1st, 2020')

# %%
df_wti_7=df_wti[df_wti.volatilitydate =='2020-05-12']
df_wti_7.set_index(pd.to_datetime(df_wti_7.volatilitydate), inplace=True)
df_wti_7.drop(columns="volatilitydate", inplace=True)
plt.rcParams['figure.figsize'] = (25,10)
plt.plot(df_wti_7.begtime,df_wti_7.price)
plt.xticks(rotation=300)
plt.title('future prices starting May 12, 2020')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'future prices starting May 12, 2020')

# %%
df_wti_8=df_wti[df_wti.volatilitydate =='2020-05-22']
df_wti_8.set_index(pd.to_datetime(df_wti_8.volatilitydate), inplace=True)
df_wti_8.drop(columns="volatilitydate", inplace=True)
plt.rcParams['figure.figsize'] = (25,10)
plt.plot(df_wti_8.begtime,df_wti_8.price)
plt.xticks(rotation=300)
plt.title('future prices starting May 22, 2020')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'future prices starting May 22, 2020')

# %%
df_wti_9=df_wti[df_wti.volatilitydate =='2020-05-29']
df_wti_9.set_index(pd.to_datetime(df_wti_9.volatilitydate), inplace=True)
df_wti_9.drop(columns="volatilitydate", inplace=True)
plt.rcParams['figure.figsize'] = (25,10)
plt.plot(df_wti_9.begtime,df_wti_9.price)
plt.xticks(rotation=300)
plt.title('future prices starting May 29, 2020')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'future prices starting May 29, 2020')
