# %%
import pandas as pd
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO


zip_in_memory = urlopen("https://www150.statcan.gc.ca/n1/tbl/csv/36100412-eng.zip").read()

z = ZipFile(BytesIO(zip_in_memory))
dict_of_dfs = {file.filename: pd.read_csv(z.open(file.filename))\
               for file in z.infolist()\
               if file.filename.endswith('.csv')}
'36100412.csv', '36100412_MetaData.csv'
dict_of_dfs['36100412.csv']
# Out:
#      REF_DATE     GEO           DGUID  \
# 0     2015-01  Canada  2016A000011124
# 1     2015-01  Canada  2016A000011124
# 2     2015-01  Canada  2016A000011124
# 3     2015-01  Canada  2016A000011124
# 4     2015-01  Canada  2016A000011124
# ...       ...     ...             ...
# 3009  2020-01  Canada  2016A000011124
# 3010  2020-01  Canada  2016A000011124
# 3011  2020-01  Canada  2016A000011124
# 3012  2020-01  Canada  2016A000011124
# 3013  2020-01  Canada  2016A000011124
#
#           Canada's international investment position Geographic region  \
# 0                                       Total assets     All countries
# 1                                       Total assets     All countries
# 2                                       Total assets     All countries
# 3                                       Total assets     All countries
# 4                                       Total assets     All countries
# ...                                              ...               ...
# ...
